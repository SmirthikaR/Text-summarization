# %% [markdown]
# <a href="https://colab.research.google.com/github/SmirthikaR/Text-summarization/blob/main/TextSummarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# %%
#URL of the webpage to scrape
url= "https://timesofindia.indiatimes.com/business/india-business/union-budget-2024-expectations-live-updates-economic-survey-finance-minister-nirmala-sitharaman-income-tax-slab/liveblog/111897014.cms"
#Send a GET request to the webpage
response = requests.get(url)
# Check if the request was successful
if response.status_code == 200:
  #Parse the webpage content
  soup = BeautifulSoup(response.content, "html.parser")
  # Extract all paragraph elements
  paragraphs = soup.find_all('p')

  # Extract text from each paragraph and save as sentences
  sentences = [para.get_text().strip() for para in paragraphs]

  # Save the sentences to a file
  with open("scraped_sentences.txt", "w", encoding="utf-8") as file:
    for sentence in sentences:
      if sentence:
        file.write(sentence + "\n")
  print("Text data has been scraped and saved as sentences.")
else:
  print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
# Text data has been scraped and saved as sentences.

# %%
import pandas as pd
df=pd.read_csv('/content/scraped_sentences.txt', delimiter='\t')
df.head()
# Out:
#   Budget 2024 Live: Key numbers to be watched for the first full Budget of Modi 3.0
# 0  Fiscal Deficit: The budgeted fiscal deficit, w...
# 1  Economic Survey 2024 Live: BJP leader Gourav V...
# 2  Budget 2024 Live: Budget for women's welfare a...
# 3  The Indian government has increased its budget...
# 4  In a post on social media platform X, Narendra...

# %%
df.shape
# Out:
# (101, 1)

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize

df = pd.read_csv('/content/scraped_sentences.txt', delimiter='\t', header=None, names=['text'])

def solve(df):
    # Load stopwords
    stopwords1 = set(stopwords.words("english"))

    # The 'text' column now exists
    summaries = []

    for index, row in df.iterrows():
        data = row['text']  # Access the text data for the current row

        # Tokenize the words
        words = word_tokenize(data)
        freqTable = {}
        for word in words:
            word = word.lower()
            if word in stopwords1:
                continue
            if word in freqTable:
                freqTable[word] += 1
            else:
                freqTable[word] = 1

        # Tokenize the sentences
        sentences = sent_tokenize(data)
        sentenceValue = {}
        for sentence in sentences:
            for word, freq in freqTable.items():
                if word in sentence.lower():
                    if sentence in sentenceValue:
                        sentenceValue[sentence] += freq
                    else:
                        sentenceValue[sentence] = freq

        # Calculate the average score for the sentences
        sumValues = sum(sentenceValue.values())
        average = int(sumValues / len(sentenceValue))

        # Generate the summary
        summary = ''
        for sentence in sentences:
            if sentence in sentenceValue and sentenceValue[sentence] > (1.2 * average):
                summary += " " + sentence

        summaries.append(summary.strip())

    # Add summaries to the DataFrame and save to a new CSV file
    df['summary'] = summaries
    df.to_csv('summarized_output.csv', index=False)
    print("Summarization completed and saved to 'summarized_output.csv'.")

# Example usage
solve(df)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Summarization completed and saved to 'summarized_output.csv'.

# %%
df.head()
# Out:
#                                                 text  \
# 0  Budget 2024 Live: Key numbers to be watched fo...
# 1  Fiscal Deficit: The budgeted fiscal deficit, w...
# 2  Economic Survey 2024 Live: BJP leader Gourav V...
# 3  Budget 2024 Live: Budget for women's welfare a...
# 4  The Indian government has increased its budget...
#
#                                              summary
# 0
# 1  The government has projected fiscal deficit at...
# 2
# 3
# 4

# %%
df['summary']
# Out:
# 0
# 1      The government has projected fiscal deficit at...
# 2
# 3
# 4
#                              ...
# 97     I extend my greetings to the countrymen on the...
# 98
# 99     Some parties doing negative politics, get rid ...
# 100
# 101
# Name: summary, Length: 102, dtype: object

# %%
column_name = 'summary'  # Replace with your column name

# Iterate through the column and print each value
for value in df[column_name]:
    print(value)
# Out:
# The government has projected fiscal deficit at 4.5 per cent of the GDP in FY26.Capital Expenditure: The government's planned capital expenditure for this fiscal year is budgeted at Rs 11.1 lakh crore, higher than Rs 9.5 lakh crore in the last fiscal year. The government has been pushing infrastructure creation and also incentivising states to step up capex.Tax Revenue: The Interim Budget had pegged gross tax revenue at Rs 38.31 lakh crore for 2024-25, an 11.46 per cent growth over the last fiscal. This includes Rs 21.99 lakh crore estimated to come from direct taxes (personal income tax + corporate tax), and Rs 16.22 lakh crore from indirect taxes (customs + excise duty + GST).GST: Goods and Services Tax (GST) collection in 2024-25 is estimated to rise to Rs 10.68 lakh crore, an increase of 11.6 per cent. The tax revenue figures will have to be watched out for in the final Budget for the 2024-25 fiscal year.Borrowing: The government's gross borrowing Budget was Rs 14.13 lakh crore in the current financial year as per the Interim Budget. The borrowing number will be watched by the market, especially on the back of more-than-expected dividend from the RBI and financial institutions.Nominal GDP: India's nominal GDP growth (real GDP plus inflation) in the current fiscal year is estimated to be 10.5 per cent to Rs 327.7 trillion as per the Interim Budget. Real GDP growth in current fiscal is projected at 7.2 per cent, as per the RBI.Dividend: The interim Budget had projected Rs 1.02 lakh crore from RBI and financial institutions.
#
#
#
#
#
# Budget 2024 Live: Sharing a post on X, Congress leader Jairam Ramesh said, "India is in its most precarious and difficult economic situation in many years.
#
# Economic think tank GTRI on Monday urged the government to cut import duty on smartphone components in the Budget as it could lead to an increase in superficial assembly plants that rely heavily on imported parts.
#
# During the trading session, the barometer dropped by 504 points or 0.62 per cent, reaching an intra-day low of 80,100.65.However, the index managed to recover most of its losses as Infosys and HDFC Bank shares advanced.The broader Nifty of the NSE dipped 21.65 points or 0.09 per cent to 24,509.25. During the day, it dropped 168.6 points or 0.68 per cent to 24,362.30.Among Sensex shares, Reliance Industries declined over 3 per cent after the company reported a 5 per cent drop in its June quarter net profit.Kotak Mahindra Bank also fell more than 3 per cent after its June quarter earnings failed to cheer investors.
#
# It said globally, widening inequality is emerging as a crucial economic challenge confronting policymakers.The 2022 State of Inequality in India report observed that in India, the top 1 per cent accounts for 6-7 per cent of the total incomes earned, while the top 10 per cent accounts for one-third of total incomes earned.
#
# Speaking with the media ahead of the start of Parliament session, Modi said the Union Budget, which will be presented on Tuesday, will set the direction for the journey of the next five years and lay the foundation for fulfilling the dream of 'Viksit Bharat' in 2047.Modi said people have given their verdict in the Lok Sabha polls and now all political parties must fight together for the country for the next five years.
#
#
#
#
#
#
#
#
#
#
#
# * Indian labour market indicators have improved in the last six years, with the unemployment rate declining to 3.2 per cent in 2022-23. * Many regulatory chokeholds, such as those related to land use, building codes, restricting sectors and hours open to women’s employment, hold back employment generation.
#
# In FY24, the US Dollar gained against virtually every major peer.
#
# "Despite its centrality in India's growth trajectory, the agriculture sector continues to face structural issues that have implications for India's economic growth," the Survey said.According to the document, policymakers must strike a delicate balance between incentivizing farmers to increase production and keeping food prices within acceptable limits.
#
# Take, for example, nations like Mexico, Vietnam, Taiwan and Korea, which were direct beneficiaries of the US’s trade diversion from China. Even while these nations increased their share of exports to the US, they also displayed a concomitant rise in Chinese FDI.106 Therefore, the world cannot completely look past China, even as it pursues China plus one, says the Economic Survey 2023-24.
#
# Economic Survey 2023-24: According to the Economic Survey 2023-24 tabled in Parliament by Finance Minister Nirmala Sitharaman, India’s march towards being a developed country will be different from China’s - and it won’t be an easy road!
#
#
# * The Indian economy is moving forward with a reformed approach to welfare, focused on empowerment, saturation approach, universal access to necessities, efficiency, cost-effectiveness, and enhanced participation of the private sector and civil society.
#
# * India’s services exports grew by 4.9 per cent to USD 341.1 billion in FY24, with growth largely driven by IT/software services and ‘other’ business services.
#
# The global backdrop for India’s march towards Viksit Bharat in 2047 could not be more different from what it was during the rise of China between 1980 and 2015. Geopolitics was largely calm with the end of the Cold War, and Western powers welcomed and even encouraged the rise of China and its integration into the world economy. Fourth, the advent of Artificial Intelligence casts a huge pall of uncertainty as to its impact on workers across all skill levels – low, semi and high.
#
# Prudent monetary policy response and calibrated trade policy measures by the Government, coupled with strong output growth, helped reduce core inflation to a four-year low in FY24. Appropriate administrative actions, including dynamic stock management, open market operations, subsidised provision of essential food items and trade policy measures, helped mitigate food inflation to a great extent. Beyond this, the medium to long-term inflation outlook will be shaped by the strengthening of price monitoring mechanisms and market intelligence as well as focussed efforts to increase the domestic production of essential food items like pulses and edible oils for which India has a great degree of import dependence,” says the Economic Survey 2023-24.
#
# * Going forward, the RBI projects inflation to fall to 4.5 per cent in FY25 and 4.1 per cent in FY26, assuming normal monsoon and no external or policy shocks.
#
#
#
# Prospects for continued strong growth in FY25 beyond look good, subject to geopolitical, financial market and climatic risks.
#
#
#
# Any escalation of geopolitical conflicts in 2024 may lead to supply dislocations, higher commodity prices, reviving inflationary pressures and stalling monetary policy easing with potential repercussions for capital flows. Conversely, increased fragmentation along geopolitical lines and renewed thrust on protectionism may distort merchandise trade growth, impacting India’s external sector.
#
# The Indian economy recovered swiftly from the pandemic, with its real GDP in FY24 being 20 per cent higher than the pre-COVID, FY20 levels. During the decade ending FY20, India grew at an average annual rate of 6.6 per cent, more or less reflecting the long-run growth prospects of the economy. If the services inflation across economies moderates faster, that may allow central banks to bring forward the monetary policy easing cycle earlier than currently anticipated. A likely reduction in policy rates by central banks of AEs, especially the Fed, will open the space for central banks of EMEs to follow the lead, bringing down the cost of capital.
#
# Private capital formation after good growth in the last three years may turn slightly more cautious because of fears of cheaper imports from countries that have excess capacity. While merchandise exports are likely to increase with improving growth prospects in AEs, services exports are also likely to witness a further uptick. A normal rainfall forecast by the India Meteorological Department and the satisfactory spread of the southwest monsoon thus far are likely to improve agriculture sector performance and support the revival of rural demand. Considering these factors, the Survey conservatively projects a real GDP growth of 6.5–7 per cent, with risks evenly balanced, cognizant of the fact that the market expectations are on the higher side, says Economic Survey 2023-24.
#
#
#
# “On the employment front, according to the annual PLFS, the all-India annual unemployment rate (persons aged 15 years and above, as per usual status) has been declining since the pandemic. From the gender perspective, the female labour force participation rate has been rising for six years, i.e., from 23.3 per cent in 2017-18 to 37 per cent in 2022-23, driven mainly by the rising participation of rural women,” says the Economic Survey 2023-24.
#
# As a result, India’s real GDP grew by 8.2 per cent in FY24, posting growth of over 7 per cent for a third consecutive year, driven by stable consumption demand and steadily improving investment demand. On the supply side, gross value added (GVA) at 2011-12 prices grew by 7.2 per cent in FY24, with growth remaining broad-based. Net taxes at constant (2011-12) prices grew by 19.1 per cent in FY24, aided by reasonably strong tax growth, both at the centre and state levels and rationalisation of subsidy expenditure.
#
# Chief Economic Adviser to the Government of India, Dr. V. Anantha Nageswaran will hold a press conference at 2:30 PM today to detail the Economic Survey 2023-24 findings.
#
#
#
# “This Budget will set the direction of the next five years of the current government and will lay a strong foundation for the dream of Viksit Bharat by 2047”, PM Modi said.He highlighted that India is the fastest growing country among the major economies with about 8 percent growth in the last three consecutive years.
#
#
#
# Budget 2024 date, time: Finance Minister Nirmala Sitharaman will present the Union Budget 2024 in Parliament as part of the Budget session which has begun today. This will be the first full Budget of PM Narendra Modi-led NDA government as being looked at as an important one since the BJP-led government has not come back with a thumping majority.
#
#
# As long as this minister (Education Minister Dharmendra Pradhan) is there, the students will not get justice.
#
# What can be done to make the new income tax regime more attractive than the old tax regime, especially for individuals who have done their tax planning based on the old regime?
#
#
#
#
#
#
# NEET as per SC norms, opposition playing politics.
#
# It will also offer valuable insights into the potential direction of the upcoming Union Budget for 2024-25.First introduced in 1950-51 as part of the budget documents, the Economic Survey was later separated from the Budget in the 1960s and is now presented a day before the Union Budget.
#
# ...We want the Finance Minister to address the real issues of jobless India, inflation, states being discriminated which are ruled by the opposition parties. In the past 10 years, we have seen such budgets which supported the super-rich and left the middle class, lower middle class and poor...
#
# “It is a matter of pride that after 60 years, a government has come to power for the third time and will present the first Budget for the third time...I have been giving guarantees to the people of the country and our mission is to bring this to the ground. This budget will also become a strong foundation of our dream of 'Viksit Bharat',” PM Modi said.
# “It is a matter of pride that after 60 years, a government has come to power for the third time and will present the first Budget for the third time...I have been giving guarantees to the people of the country and our mission is to bring this to the ground.
#
# Prime Minister Narendra Modi says "...It is a matter of pride that after 60 years, a government has come to power for the third time and will present the first Budget for the third time...I have been giving guarantees to the people of the country and our mission is to bring this to the ground.
#
# I extend my greetings to the countrymen on the first Monday of Sawan. The monsoon session of Parliament is starting today.
#
# Some parties doing negative politics, get rid of past bitterness and come together, says PM Modi"I would like to request all the MPs of the country that from January till now we have fought as much as we had to, but now that period is over, the public has given its verdict.

# %%
# !pip install rouge_score
# Out:
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.66.5)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=a70f632b5fdd47919166df3a4d514a2025f2190c4ac9a7bc1a92d8f7d4b63b38
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2

# %%
# Evaluation metrix
from rouge_score import rouge_scorer, scoring

# Define the function to calculate ROUGE scores
def calculate_rouge_scores(reference, summary):
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    scores = scorer.score(reference, summary)
    return scores
# Calculate ROUGE scores for each pair of reference and summary
df['rouge_scores'] = df.apply(lambda row: calculate_rouge_scores(row['text'], row['summary']), axis=1)

# Display the scores
for idx, row in df.iterrows():
    print(f"Summary {idx + 1} ROUGE scores:")
    print(f"ROUGE-1: {row['rouge_scores']['rouge1']}")
    print(f"ROUGE-2: {row['rouge_scores']['rouge2']}")
    print(f"ROUGE-L: {row['rouge_scores']['rougeL']}")
    print("\n")
# Out:
# Summary 1 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 2 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.6492027334851936, fmeasure=0.7872928176795579)
# ROUGE-2: Score(precision=0.9964788732394366, recall=0.6461187214611872, fmeasure=0.7839335180055402)
# ROUGE-L: Score(precision=1.0, recall=0.6492027334851936, fmeasure=0.7872928176795579)
#
#
# Summary 3 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 4 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 5 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 6 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 7 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 8 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.3880597014925373, fmeasure=0.5591397849462366)
# ROUGE-2: Score(precision=1.0, recall=0.3787878787878788, fmeasure=0.5494505494505494)
# ROUGE-L: Score(precision=1.0, recall=0.3880597014925373, fmeasure=0.5591397849462366)
#
#
# Summary 9 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 10 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.3711340206185567, fmeasure=0.5413533834586466)
# ROUGE-2: Score(precision=1.0, recall=0.3645833333333333, fmeasure=0.5343511450381679)
# ROUGE-L: Score(precision=1.0, recall=0.3711340206185567, fmeasure=0.5413533834586466)
#
#
# Summary 11 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 12 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.545045045045045, fmeasure=0.705539358600583)
# ROUGE-2: Score(precision=1.0, recall=0.5429864253393665, fmeasure=0.7038123167155426)
# ROUGE-L: Score(precision=1.0, recall=0.545045045045045, fmeasure=0.705539358600583)
#
#
# Summary 13 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 14 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.5894736842105263, fmeasure=0.7417218543046357)
# ROUGE-2: Score(precision=1.0, recall=0.5851063829787234, fmeasure=0.7382550335570469)
# ROUGE-L: Score(precision=1.0, recall=0.5894736842105263, fmeasure=0.7417218543046357)
#
#
# Summary 15 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 16 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.3605769230769231, fmeasure=0.5300353356890459)
# ROUGE-2: Score(precision=1.0, recall=0.357487922705314, fmeasure=0.5266903914590747)
# ROUGE-L: Score(precision=1.0, recall=0.3605769230769231, fmeasure=0.5300353356890459)
#
#
# Summary 17 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 18 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 19 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 20 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 21 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 22 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 23 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 24 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 25 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 26 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 27 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 28 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.25925925925925924, fmeasure=0.4117647058823529)
# ROUGE-2: Score(precision=0.9791666666666666, recall=0.25, fmeasure=0.39830508474576276)
# ROUGE-L: Score(precision=1.0, recall=0.25925925925925924, fmeasure=0.4117647058823529)
#
#
# Summary 29 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 30 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.2682926829268293, fmeasure=0.4230769230769231)
# ROUGE-2: Score(precision=1.0, recall=0.25, fmeasure=0.4)
# ROUGE-L: Score(precision=1.0, recall=0.2682926829268293, fmeasure=0.4230769230769231)
#
#
# Summary 31 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 32 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.3875968992248062, fmeasure=0.558659217877095)
# ROUGE-2: Score(precision=1.0, recall=0.3828125, fmeasure=0.5536723163841808)
# ROUGE-L: Score(precision=1.0, recall=0.3875968992248062, fmeasure=0.558659217877095)
#
#
# Summary 33 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 34 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.7558139534883721, fmeasure=0.8609271523178808)
# ROUGE-2: Score(precision=1.0, recall=0.7529411764705882, fmeasure=0.8590604026845637)
# ROUGE-L: Score(precision=1.0, recall=0.7558139534883721, fmeasure=0.8609271523178808)
#
#
# Summary 35 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 36 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.9111111111111111, fmeasure=0.9534883720930233)
# ROUGE-2: Score(precision=1.0, recall=0.9090909090909091, fmeasure=0.9523809523809523)
# ROUGE-L: Score(precision=1.0, recall=0.9111111111111111, fmeasure=0.9534883720930233)
#
#
# Summary 37 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 38 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 39 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.2236842105263158, fmeasure=0.3655913978494624)
# ROUGE-2: Score(precision=1.0, recall=0.2185430463576159, fmeasure=0.358695652173913)
# ROUGE-L: Score(precision=1.0, recall=0.2236842105263158, fmeasure=0.3655913978494624)
#
#
# Summary 40 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 41 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.232, fmeasure=0.37662337662337664)
# ROUGE-2: Score(precision=1.0, recall=0.22580645161290322, fmeasure=0.3684210526315789)
# ROUGE-L: Score(precision=1.0, recall=0.232, fmeasure=0.37662337662337664)
#
#
# Summary 42 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 43 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.5089820359281437, fmeasure=0.6746031746031746)
# ROUGE-2: Score(precision=0.9761904761904762, recall=0.4939759036144578, fmeasure=0.656)
# ROUGE-L: Score(precision=1.0, recall=0.5089820359281437, fmeasure=0.6746031746031746)
#
#
# Summary 44 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 45 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.49344978165938863, fmeasure=0.6608187134502924)
# ROUGE-2: Score(precision=0.9910714285714286, recall=0.4868421052631579, fmeasure=0.6529411764705882)
# ROUGE-L: Score(precision=1.0, recall=0.49344978165938863, fmeasure=0.6608187134502924)
#
#
# Summary 46 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 47 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.26956521739130435, fmeasure=0.4246575342465753)
# ROUGE-2: Score(precision=1.0, recall=0.2631578947368421, fmeasure=0.4166666666666667)
# ROUGE-L: Score(precision=1.0, recall=0.26956521739130435, fmeasure=0.4246575342465753)
#
#
# Summary 48 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 49 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 50 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 51 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.32727272727272727, fmeasure=0.4931506849315069)
# ROUGE-2: Score(precision=1.0, recall=0.3148148148148148, fmeasure=0.4788732394366197)
# ROUGE-L: Score(precision=1.0, recall=0.32727272727272727, fmeasure=0.4931506849315069)
#
#
# Summary 52 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 53 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 54 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 55 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.2347417840375587, fmeasure=0.38022813688212925)
# ROUGE-2: Score(precision=0.9795918367346939, recall=0.22641509433962265, fmeasure=0.36781609195402304)
# ROUGE-L: Score(precision=1.0, recall=0.2347417840375587, fmeasure=0.38022813688212925)
#
#
# Summary 56 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 57 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.42424242424242425, fmeasure=0.5957446808510638)
# ROUGE-2: Score(precision=0.9819819819819819, recall=0.4144486692015209, fmeasure=0.5828877005347595)
# ROUGE-L: Score(precision=1.0, recall=0.42424242424242425, fmeasure=0.5957446808510638)
#
#
# Summary 58 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 59 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.6684782608695652, fmeasure=0.8013029315960912)
# ROUGE-2: Score(precision=0.9918032786885246, recall=0.6612021857923497, fmeasure=0.7934426229508196)
# ROUGE-L: Score(precision=1.0, recall=0.6684782608695652, fmeasure=0.8013029315960912)
#
#
# Summary 60 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 61 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 62 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 63 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.6694915254237288, fmeasure=0.8020304568527918)
# ROUGE-2: Score(precision=0.9871794871794872, recall=0.6581196581196581, fmeasure=0.7897435897435897)
# ROUGE-L: Score(precision=1.0, recall=0.6694915254237288, fmeasure=0.8020304568527918)
#
#
# Summary 64 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 65 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.6291390728476821, fmeasure=0.7723577235772359)
# ROUGE-2: Score(precision=1.0, recall=0.6266666666666667, fmeasure=0.7704918032786886)
# ROUGE-L: Score(precision=1.0, recall=0.6291390728476821, fmeasure=0.7723577235772359)
#
#
# Summary 66 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 67 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.6976744186046512, fmeasure=0.8219178082191781)
# ROUGE-2: Score(precision=1.0, recall=0.6904761904761905, fmeasure=0.8169014084507042)
# ROUGE-L: Score(precision=1.0, recall=0.6976744186046512, fmeasure=0.8219178082191781)
#
#
# Summary 68 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 69 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 70 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 71 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.7887323943661971, fmeasure=0.8818897637795275)
# ROUGE-2: Score(precision=1.0, recall=0.7857142857142857, fmeasure=0.88)
# ROUGE-L: Score(precision=1.0, recall=0.7887323943661971, fmeasure=0.8818897637795275)
#
#
# Summary 72 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 73 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 74 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 75 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.9384615384615385, fmeasure=0.9682539682539683)
# ROUGE-2: Score(precision=1.0, recall=0.9375, fmeasure=0.967741935483871)
# ROUGE-L: Score(precision=1.0, recall=0.9384615384615385, fmeasure=0.9682539682539683)
#
#
# Summary 76 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 77 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 78 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.4473684210526316, fmeasure=0.6181818181818182)
# ROUGE-2: Score(precision=1.0, recall=0.43243243243243246, fmeasure=0.6037735849056604)
# ROUGE-L: Score(precision=1.0, recall=0.4473684210526316, fmeasure=0.6181818181818182)
#
#
# Summary 79 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 80 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.7804878048780488, fmeasure=0.8767123287671234)
# ROUGE-2: Score(precision=1.0, recall=0.775, fmeasure=0.8732394366197184)
# ROUGE-L: Score(precision=1.0, recall=0.7804878048780488, fmeasure=0.8767123287671234)
#
#
# Summary 81 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 82 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 83 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 84 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 85 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 86 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 87 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.5714285714285714, fmeasure=0.7272727272727273)
# ROUGE-2: Score(precision=1.0, recall=0.5384615384615384, fmeasure=0.7000000000000001)
# ROUGE-L: Score(precision=1.0, recall=0.5714285714285714, fmeasure=0.7272727272727273)
#
#
# Summary 88 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 89 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.30177514792899407, fmeasure=0.4636363636363636)
# ROUGE-2: Score(precision=1.0, recall=0.2976190476190476, fmeasure=0.4587155963302752)
# ROUGE-L: Score(precision=1.0, recall=0.30177514792899407, fmeasure=0.4636363636363636)
#
#
# Summary 90 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 91 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.6621621621621622, fmeasure=0.7967479674796748)
# ROUGE-2: Score(precision=0.9791666666666666, recall=0.6438356164383562, fmeasure=0.7768595041322315)
# ROUGE-L: Score(precision=1.0, recall=0.6621621621621622, fmeasure=0.7967479674796748)
#
#
# Summary 92 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 93 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.7083333333333334, fmeasure=0.8292682926829268)
# ROUGE-2: Score(precision=1.0, recall=0.7052631578947368, fmeasure=0.8271604938271605)
# ROUGE-L: Score(precision=1.0, recall=0.7083333333333334, fmeasure=0.8292682926829268)
#
#
# Summary 94 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.5543478260869565, fmeasure=0.7132867132867133)
# ROUGE-2: Score(precision=1.0, recall=0.5494505494505495, fmeasure=0.7092198581560284)
# ROUGE-L: Score(precision=1.0, recall=0.5543478260869565, fmeasure=0.7132867132867133)
#
#
# Summary 95 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 96 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.6021505376344086, fmeasure=0.7516778523489933)
# ROUGE-2: Score(precision=1.0, recall=0.5978260869565217, fmeasure=0.7482993197278911)
# ROUGE-L: Score(precision=1.0, recall=0.6021505376344086, fmeasure=0.7516778523489933)
#
#
# Summary 97 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 98 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.4117647058823529, fmeasure=0.5833333333333334)
# ROUGE-2: Score(precision=1.0, recall=0.4, fmeasure=0.5714285714285715)
# ROUGE-L: Score(precision=1.0, recall=0.4117647058823529, fmeasure=0.5833333333333334)
#
#
# Summary 99 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 100 ROUGE scores:
# ROUGE-1: Score(precision=1.0, recall=0.4690265486725664, fmeasure=0.6385542168674698)
# ROUGE-2: Score(precision=1.0, recall=0.4642857142857143, fmeasure=0.6341463414634146)
# ROUGE-L: Score(precision=1.0, recall=0.4690265486725664, fmeasure=0.6385542168674698)
#
#
# Summary 101 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)
#
#
# Summary 102 ROUGE scores:
# ROUGE-1: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-2: Score(precision=0.0, recall=0.0, fmeasure=0.0)
# ROUGE-L: Score(precision=0, recall=0, fmeasure=0)

# %%
#Abstractive summarization
data=pd.read_csv('/content/scraped_sentences.txt', delimiter='\t')
data.head()
from transformers import pipeline

def summarize_text(text, summarizer, max_length=150):
    # Summarize the text using the summarizer
    summary = summarizer(text, max_length=11, min_length=5, do_sample=False)[0]['summary_text']
    return summary

def solve(data,model='t5-base'):

    # Assuming the text data is in a column named 'text'
    if 'text' not in df.columns:
        print("The dataset must contain a 'text' column.")
        return

    # Load the summarization model
    summarizer = pipeline("summarization", model=model)

    # Summarize each text entry in the column
    df['summary'] = df['text'].apply(lambda x: summarize_text(x, summarizer))

    # Save the summaries to a new CSV file
    output_path = 'summarized_output.csv'
    df.to_csv(output_path, index=False)
    print(f"Summarization completed and saved to '{output_path}'.")

# Example usage
solve(data)
# Out:
# Summarization completed and saved to 'summarized_output.csv'.

# %%
data1=pd.read_csv('/content/summarized_output.csv')
data1.head()
column_name = 'summary'  # Replace with your column name

# Iterate through the column and print each value
for value in df[column_name]:
    print(value)
# Out:
# Budget 2024 Live: Key numbers to be watched
# fiscal deficit is the difference between government expenditure and income
# BJP leader: "the survey that has come
# budget for women's welfare and empowerment schemes surge
# the budget for women's welfare and empowerment has
# in a post on social media platform X
# he identifies areas for further growth and
# the Economic Survey 2023-24 presents a cherry
# GTRI urges govt not to cut
# think tank urges government to cut import duty on
# Union Budget 2024: stock markets close lower on
# the Sensex closed at 80,502.0
# tax policies to play major role in tackling income
# tax policies will have a major role to play
# Modi slams opposition for
# prime minister says some parties have practised "negative
# india's contribution to global value chain trade has
# CEA: India's contribution to global value
# Economic Survey 2024 Live: Chief econ
# private capex has recovered after decline seen in 20
# CEA's Economic Survey 2024 live:
# anantha nageswararan says
# Survey highlights govt's crucial role in
# the survey says the government has a crucial role
# Economic Survey 2024 Live: Chie economic advisor
# "we all needs hands on table," says chief
# Economic Survey 2024 Live: Indian labour market indicators
# net payroll additions under EPFO have more than
# Rupee one of the least volatile currencies in
# the US Dollar gained against virtually every major peer in
# Agriculture Survey 2024 Live: Pre-budget
# he pre-budget economic survey cite
# Can the world not look past China?
# will China plus one result in a total movement
# India's march to ‘Viks
# India's march towards being a developed country
# Economic Survey 2023-24 tabled in Parliament by
# The Economic Survey 2024 Live: Welfare economics
# the education sector is bustling with the across-
# Economic Survey 2024 Live: How India’s
# india’s rank in the world bank’s
# India’s rise to Viksit B
# big changes are afoot in the geopoli
# The Economic Survey 2024 Live: Where is inflation
# the pandemic and subsequent geo-polit
# Achieving long-term price stability requires
# RBI projects inflation to fall to 4.5 per cent
# Inflationary pressures are expected to increase
# retail inflation declined to 5.4 per cent in FY
# Economic Survey 2024 Live: FY24 GDP 20%
# the real GDP in FY24 was 20 per cent
# Economic Survey 2024 Live: Private investment to be
# gross fixed capital formation increased by 9 per cent in
# The Economic Survey 2024 Live: Global headwind
# any escalation of geopolitical
# Economic Survey 2024 Live: Indian economy recovered swift
# india's real GDP in FY24 was 20%
# Economic Survey 2024 Live: What is the outlook
# domestic growth drivers have supported economic growth in FY24
# Real GDP growth for FY25 seen at 6.5
# the survey conservatively projects a real GDP growth
# Survey 2024 Live: All-India annual unemployment
# all-India annual unemployment rate has been declining since
# Economic Survey 2024 Live: India’s economy
# real GDP grew by 8.2% in FY24
# Economic Survey 2024 Live: Chief Economic Advisor to
# a press conference will be held at 2:30
# Economic Survey 2024 Live: FM Nirmal
# Nirmala Sitharaman tabled
# PM Modi explains what to expect from Union
# india is the fastest growing country among the major economies
# Economic Survey Live: FM Nirmala Si
# the Parliament's Budget session has begun .
# Union Budget 2024 date, time: when will
# this will be the first full Budget of PM Nar
# this will be the first full Budget of PM Nar
# Samajwadi Party MP Akhi
# there are some centres where more than 2,000 students
# Budget 2024 live: How can Budget make the
# toi Online survey of personal tax experts finds out
# what can be done to make the new income tax
# Economic Survey Live: Education minister holds Congress responsible for
# education minister defends government's action by
# Rahul Gandhi: NEET leaks serious system
# the rich can buy education but the poor cant
# Economic Survey Live: NEET being raised in the
# NEET was brought by UPA government .
# Economic Survey Live: What is Economic Survey?
# the survey aims to provide a comprehensive overview
# Economic Survey 2024 Live:Congress MP Man
# we want the finance minister to address the real issues
# Budget 2024 Live: What PM Modi said
# amritkaal will present its first budget
# 'it is a matter of pride that
# PM Modi says the budget will decide the direction
# a government has come to power for the third
# 'This should be a positive session,
# the monsoon session of parliament is starting
# PM Modi appeals to Opposition ahead of
# some parties doing negative politics, get rid of past
# Prime Minister's address ahead of budget session
# 'Viksit Bharat
